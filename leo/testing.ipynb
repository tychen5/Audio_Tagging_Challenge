# %%
import numpy as np
from random import shuffle
from math import log, floor
import pandas as pd
import tensorflow as tf
import tensorboard as tb
from keras import backend as K
from keras.models import *
from keras.layers import *
from keras.activations import *
from keras.callbacks import *
from keras.utils import *
from keras.layers.advanced_activations import *
from collections import Counter
from keras import *
from keras.engine.topology import *
from keras.optimizers import *
import keras
# import pandas as pd
import glob
from sklearn.semi_supervised import *
import pickle
from keras.applications import *
from keras.preprocessing.image import *
from keras.losses import mse, binary_crossentropy
import pandas as pd # data frame
import numpy as np # matrix math
from scipy.io import wavfile # reading the wavfile
from sklearn.utils import shuffle # shuffling of data
from random import sample # random selection
from tqdm import tqdm # progress bar
import matplotlib.pyplot as plt # to view graphs
import wave
from math import log, floor
# audio processing
from scipy import signal # audio processing
from scipy.fftpack import dct
import librosa # library for audio processing
import numpy as np
import pandas as pd
from sklearn.decomposition import *
from sklearn.cluster import KMeans
import sys, os
import random,math
from tqdm import tqdm ##
# from xgboost.sklearn import XGBClassifier
from sklearn.utils import shuffle # shuffling of data
from random import sample # random selection
from tqdm import tqdm # progress bar
# audio processing
from scipy import signal # audio processing
from scipy.fftpack import dct
import librosa # library for audio processing
# import xgboost as xgb
# import lightgbm as lgb
# import catboost as ctb
from keras.utils import *
from sklearn.ensemble import *
import pickle
# from bayes_opt import BayesianOptimization
from logHandler import Logger
from utils import readCSV, getPath, writePickle,readPickle
from keras.regularizers import l2
from keras.callbacks import History ,ModelCheckpoint, EarlyStopping

import resnet
from random_eraser import get_random_eraser
from mixup_generator import MixupGenerator

# %%
predict_path = sys.argv[1]

# %% [markdown]
# ## voting 3. ensemble model predictions

# %%
# type_ = 'mfcc7' #要抽取哪一個種類的unverified trainX出來去re-train
un_or_test = 'combine' # unverified or test
phase = 'phase4'

folder = 'data/'+phase+'/'+un_or_test+'/' #共同predict對unverified data的結果


acc_df = pd.read_csv('data/'+phase+'/weight_accF.csv') # acc csv檔名格式: (csv,acc)
# acc_df.columns = ['unverified','test','acc']
acc_df.columns = [un_or_test,'acc']
acc_df = acc_df.filter([un_or_test,'acc'])
files = os.listdir(folder)

ratio_all=0
for i,csv in enumerate(files):
    if csv.startswith('valid_acc'):
        continue
    else:
        ratio = acc_df[acc_df[un_or_test] == csv]['acc'].values[0]
#         print(ratio)
        ratio_all += ratio
    df = pd.read_csv(os.path.join(folder,csv)) #ori method
#     df = pd.read_csv(os.path.join(folder,csv),header=0,index_col=0) # new method
#     df.sort_values("fname", inplace=True)
    if df.iloc[0,0] == 'fname':
        df = df.drop(0,axis=0)
#     df = df.drop(0,axis=1) #ori method
    df = df.drop(['fname'],axis=1) #mew mthod

    if i==0:
        train_X = df.values*ratio#+4e-4
    else:
#         try:
#         train_X *= df.values**ratio+4e-4
        train_X += df.values*ratio#+1e-3
#         except:
#             train_X += df.values[5763:]*ratio
print(train_X.shape)
# train_X = train_X ** (1/ratio_all)
train_X = train_X /ratio_all
print(sum(train_X[0]),sum(train_X[1000]),sum(train_X[2000]))
print(sum(sum(train_X))/9400)
reverse_dict = pickle.load(open('data/map_reverse.pkl' , 'rb'))
# Out:
# (9400, 41)
# 0.9999999878836174 0.9999999984855509 1.0000000105663593
# 1.00000000313519

# %%
fname_test = pd.read_csv('data/sample_submission.csv')
fname_test['label'] = 'none'
fname = fname_test # 記得註解掉如果是un+test
'''
fname_un = pd.read_csv('data/train_label.csv')
fname_un = fname_un[fname_un.manually_verified==0]
fname_un = fname_un.drop(['manually_verified'],axis=1)
fname = fname_un.append(fname_test)
fname.sort_values('fname',inplace=True)
fname.reset_index(drop=True,inplace=True)
'''
fname['label_verified'] = "none"
fname['verified_confidence']=0.0
print(len(fname))
for i,r in fname.iterrows():
    top3 = train_X[i].argsort()[-3:][::-1]
    result = [reverse_dict[x] for x in top3]
    s = ' '.join(result)
    fname.iloc[i,2] = s#np.argmax(train_X[i])
    fname.iloc[i,3] = max(train_X[i])

df = fname
print(df['verified_confidence'].min(),df['verified_confidence'].mean(), df['verified_confidence'].std() )
# (df)
# Out:
# 9400
# 0.08217809405680532 0.7515160645699978 0.26395262115225376
#              fname label                                     label_verified  \
# 0     00063640.wav  none                   Shatter Keys_jangling Tambourine
# 1     0013a1db.wav  none                     Flute Trumpet Violin_or_fiddle
# 2     002bb878.wav  none                 Bass_drum Knock Gunshot_or_gunfire
# 3     002d392d.wav  none                        Bass_drum Knock Double_bass
# 4     00326aa9.wav  none                            Oboe Clarinet Bass_drum
# 5     0038a046.wav  none                     Bass_drum Electric_piano Knock
# 6     003995fa.wav  none                          Squeak Clarinet Telephone
# 7     005ae625.wav  none                     Acoustic_guitar Cello Clarinet
# 8     007759c4.wav  none                           Clarinet Flute Telephone
# 9     008afd93.wav  none                              Saxophone Flute Cello
# 10    00a161c0.wav  none                               Cello Clarinet Flute
# 11    00a7a2f6.wav  none                             Clarinet Trumpet Cello
# 12    00ae03f6.wav  none                                Chime Telephone Bus
# 13    00b2404e.wav  none                        Cello Double_bass Bass_drum
# 14    00beb030.wav  none                              Clarinet Oboe Trumpet
# 15    00c4d5b8.wav  none                   Acoustic_guitar Gong Double_bass
# 16    00c92c05.wav  none              Acoustic_guitar Clarinet Glockenspiel
# 17    00ccf065.wav  none                    Bass_drum Flute Finger_snapping
# 18    00d0ab77.wav  none                             Clarinet Trumpet Cello
# 19    00dffe3a.wav  none                             Bass_drum Knock Hi-hat
# 20    00e33205.wav  none                              Clarinet Trumpet Oboe
# 21    00e7ed07.wav  none                            Flute Saxophone Trumpet
# 22    00eac343.wav  none                  Electric_piano Telephone Clarinet
# 23    00f2f692.wav  none               Hi-hat Violin_or_fiddle Glockenspiel
# 24    0102a895.wav  none                  Cello Double_bass Acoustic_guitar
# 25    010a0b3a.wav  none                   Shatter Tambourine Keys_jangling
# 26    010eed01.wav  none                   Trumpet Knock Gunshot_or_gunfire
# 27    01115622.wav  none                       Shatter Hi-hat Keys_jangling
# 28    01198b7e.wav  none                            Clarinet Oboe Saxophone
# 29    01207ce5.wav  none           Tearing Keys_jangling Gunshot_or_gunfire
# ...            ...   ...                                                ...
# 9370  ff812cf5.wav  none                 Bass_drum Knock Gunshot_or_gunfire
# 9371  ff81cc5d.wav  none                           Saxophone Flute Applause
# 9372  ff85f513.wav  none                    Bass_drum Finger_snapping Knock
# 9373  ff8c555d.wav  none             Gunshot_or_gunfire Fireworks Bass_drum
# 9374  ff8cfb2d.wav  none                   Double_bass Knock Electric_piano
# 9375  ff927bb1.wav  none                            Clarinet Saxophone Oboe
# 9376  ff96680f.wav  none                               Meow Squeak Laughter
# 9377  ff97972c.wav  none                             Clarinet Trumpet Flute
# 9378  ffa502ed.wav  none                           Clarinet Saxophone Flute
# 9379  ffa69cfc.wav  none           Telephone Electric_piano Acoustic_guitar
# 9380  ffaca82d.wav  none             Scissors Keys_jangling Finger_snapping
# 9381  ffae796c.wav  none                         Trumpet Saxophone Applause
# 9382  ffb6eb52.wav  none     Cowbell Burping_or_eructation Violin_or_fiddle
# 9383  ffb6f4da.wav  none  Bass_drum Gunshot_or_gunfire Burping_or_eructa...
# 9384  ffb75ce0.wav  none        Acoustic_guitar Glockenspiel Electric_piano
# 9385  ffba7963.wav  none                           Clarinet Flute Saxophone
# 9386  ffbc5fb8.wav  none                            Cello Saxophone Trumpet
# 9387  ffbe4fbf.wav  none                            Trumpet Flute Saxophone
# 9388  ffc9555f.wav  none        Glockenspiel Finger_snapping Microwave_oven
# 9389  ffd137a4.wav  none        Acoustic_guitar Electric_piano Glockenspiel
# 9390  ffd48624.wav  none                             Trumpet Cello Clarinet
# 9391  ffd5e900.wav  none                             Trumpet Cello Clarinet
# 9392  ffd64be4.wav  none             Drawer_open_or_close Snare_drum Squeak
# 9393  ffd6e84f.wav  none         Bass_drum Double_bass Drawer_open_or_close
# 9394  ffd9d282.wav  none                                 Clarinet Oboe Gong
# 9395  ffe76321.wav  none                  Gunshot_or_gunfire Bass_drum Fart
# 9396  ffe8d42d.wav  none            Acoustic_guitar Computer_keyboard Knock
# 9397  ffeba2cd.wav  none                   Cello Harmonica Violin_or_fiddle
# 9398  fff6d073.wav  none                        Bass_drum Double_bass Knock
# 9399  fff8d22d.wav  none                                   Squeak Meow Fart
#
#       verified_confidence
# 0                0.595603
# 1                0.823982
# 2                0.491480
# 3                0.935640
# 4                0.975470
# 5                0.671415
# 6                0.260038
# 7                0.660926
# 8                0.223711
# 9                0.976477
# 10               0.985293
# 11               0.935573
# 12               0.944375
# 13               0.959563
# 14               0.903992
# 15               0.897438
# 16               0.894115
# 17               0.982103
# 18               0.962695
# 19               0.981810
# 20               0.967414
# 21               0.920559
# 22               0.542925
# 23               0.704936
# 24               0.985368
# 25               0.548433
# 26               0.321260
# 27               0.886371
# 28               0.917577
# 29               0.596233
# ...                   ...
# 9370             0.963699
# 9371             0.984707
# 9372             0.976537
# 9373             0.979882
# 9374             0.957441
# 9375             0.989398
# 9376             0.905367
# 9377             0.956338
# 9378             0.950939
# 9379             0.816395
# 9380             0.714982
# 9381             0.985028
# 9382             0.924010
# 9383             0.676878
# 9384             0.953686
# 9385             0.870044
# 9386             0.971468
# 9387             0.980884
# 9388             0.252908
# 9389             0.928532
# 9390             0.742519
# 9391             0.813656
# 9392             0.406631
# 9393             0.572429
# 9394             0.580626
# 9395             0.473614
# 9396             0.360670
# 9397             0.785285
# 9398             0.976641
# 9399             0.413791
#
# [9400 rows x 4 columns]

# %%
df_fin = df[df.label=='none']
df_fin = df_fin.filter(['fname','label_verified'])
df_fin.columns = ['fname','label']
# df_fin.to_csv(predict_path,index=False)
# df_fin
# Out:
#              fname                                              label
# 0     00063640.wav                   Shatter Keys_jangling Tambourine
# 1     0013a1db.wav                     Flute Trumpet Violin_or_fiddle
# 2     002bb878.wav                 Bass_drum Knock Gunshot_or_gunfire
# 3     002d392d.wav                        Bass_drum Knock Double_bass
# 4     00326aa9.wav                            Oboe Clarinet Bass_drum
# 5     0038a046.wav                     Bass_drum Electric_piano Knock
# 6     003995fa.wav                          Squeak Clarinet Telephone
# 7     005ae625.wav                     Acoustic_guitar Cello Clarinet
# 8     007759c4.wav                           Clarinet Flute Telephone
# 9     008afd93.wav                              Saxophone Flute Cello
# 10    00a161c0.wav                               Cello Clarinet Flute
# 11    00a7a2f6.wav                             Clarinet Trumpet Cello
# 12    00ae03f6.wav                                Chime Telephone Bus
# 13    00b2404e.wav                        Cello Double_bass Bass_drum
# 14    00beb030.wav                              Clarinet Oboe Trumpet
# 15    00c4d5b8.wav                   Acoustic_guitar Gong Double_bass
# 16    00c92c05.wav              Acoustic_guitar Clarinet Glockenspiel
# 17    00ccf065.wav                    Bass_drum Flute Finger_snapping
# 18    00d0ab77.wav                             Clarinet Trumpet Cello
# 19    00dffe3a.wav                             Bass_drum Knock Hi-hat
# 20    00e33205.wav                              Clarinet Trumpet Oboe
# 21    00e7ed07.wav                            Flute Saxophone Trumpet
# 22    00eac343.wav                  Electric_piano Telephone Clarinet
# 23    00f2f692.wav               Hi-hat Violin_or_fiddle Glockenspiel
# 24    0102a895.wav                  Cello Double_bass Acoustic_guitar
# 25    010a0b3a.wav                   Shatter Tambourine Keys_jangling
# 26    010eed01.wav                   Trumpet Knock Gunshot_or_gunfire
# 27    01115622.wav                       Shatter Hi-hat Keys_jangling
# 28    01198b7e.wav                            Clarinet Oboe Saxophone
# 29    01207ce5.wav           Tearing Keys_jangling Gunshot_or_gunfire
# ...            ...                                                ...
# 9370  ff812cf5.wav                 Bass_drum Knock Gunshot_or_gunfire
# 9371  ff81cc5d.wav                           Saxophone Flute Applause
# 9372  ff85f513.wav                    Bass_drum Finger_snapping Knock
# 9373  ff8c555d.wav             Gunshot_or_gunfire Fireworks Bass_drum
# 9374  ff8cfb2d.wav                   Double_bass Knock Electric_piano
# 9375  ff927bb1.wav                            Clarinet Saxophone Oboe
# 9376  ff96680f.wav                               Meow Squeak Laughter
# 9377  ff97972c.wav                             Clarinet Trumpet Flute
# 9378  ffa502ed.wav                           Clarinet Saxophone Flute
# 9379  ffa69cfc.wav           Telephone Electric_piano Acoustic_guitar
# 9380  ffaca82d.wav             Scissors Keys_jangling Finger_snapping
# 9381  ffae796c.wav                         Trumpet Saxophone Applause
# 9382  ffb6eb52.wav     Cowbell Burping_or_eructation Violin_or_fiddle
# 9383  ffb6f4da.wav  Bass_drum Gunshot_or_gunfire Burping_or_eructa...
# 9384  ffb75ce0.wav        Acoustic_guitar Glockenspiel Electric_piano
# 9385  ffba7963.wav                           Clarinet Flute Saxophone
# 9386  ffbc5fb8.wav                            Cello Saxophone Trumpet
# 9387  ffbe4fbf.wav                            Trumpet Flute Saxophone
# 9388  ffc9555f.wav        Glockenspiel Finger_snapping Microwave_oven
# 9389  ffd137a4.wav        Acoustic_guitar Electric_piano Glockenspiel
# 9390  ffd48624.wav                             Trumpet Cello Clarinet
# 9391  ffd5e900.wav                             Trumpet Cello Clarinet
# 9392  ffd64be4.wav             Drawer_open_or_close Snare_drum Squeak
# 9393  ffd6e84f.wav         Bass_drum Double_bass Drawer_open_or_close
# 9394  ffd9d282.wav                                 Clarinet Oboe Gong
# 9395  ffe76321.wav                  Gunshot_or_gunfire Bass_drum Fart
# 9396  ffe8d42d.wav            Acoustic_guitar Computer_keyboard Knock
# 9397  ffeba2cd.wav                   Cello Harmonica Violin_or_fiddle
# 9398  fff6d073.wav                        Bass_drum Double_bass Knock
# 9399  fff8d22d.wav                                   Squeak Meow Fart
#
# [9400 rows x 2 columns]

# %%
df_ens = pd.DataFrame(df_fin.label.str.split(' ',2).tolist(),columns=['1','2','3'])
df_ens = pd.merge(pd.DataFrame(df_fin.fname),df_ens,how='inner',right_index=True,left_index=True)
df_ens['lp']='none'
# df_ens
# Out:
#              fname                     1                      2  \
# 0     00063640.wav               Shatter          Keys_jangling
# 1     0013a1db.wav                 Flute                Trumpet
# 2     002bb878.wav             Bass_drum                  Knock
# 3     002d392d.wav             Bass_drum                  Knock
# 4     00326aa9.wav                  Oboe               Clarinet
# 5     0038a046.wav             Bass_drum         Electric_piano
# 6     003995fa.wav                Squeak               Clarinet
# 7     005ae625.wav       Acoustic_guitar                  Cello
# 8     007759c4.wav              Clarinet                  Flute
# 9     008afd93.wav             Saxophone                  Flute
# 10    00a161c0.wav                 Cello               Clarinet
# 11    00a7a2f6.wav              Clarinet                Trumpet
# 12    00ae03f6.wav                 Chime              Telephone
# 13    00b2404e.wav                 Cello            Double_bass
# 14    00beb030.wav              Clarinet                   Oboe
# 15    00c4d5b8.wav       Acoustic_guitar                   Gong
# 16    00c92c05.wav       Acoustic_guitar               Clarinet
# 17    00ccf065.wav             Bass_drum                  Flute
# 18    00d0ab77.wav              Clarinet                Trumpet
# 19    00dffe3a.wav             Bass_drum                  Knock
# 20    00e33205.wav              Clarinet                Trumpet
# 21    00e7ed07.wav                 Flute              Saxophone
# 22    00eac343.wav        Electric_piano              Telephone
# 23    00f2f692.wav                Hi-hat       Violin_or_fiddle
# 24    0102a895.wav                 Cello            Double_bass
# 25    010a0b3a.wav               Shatter             Tambourine
# 26    010eed01.wav               Trumpet                  Knock
# 27    01115622.wav               Shatter                 Hi-hat
# 28    01198b7e.wav              Clarinet                   Oboe
# 29    01207ce5.wav               Tearing          Keys_jangling
# ...            ...                   ...                    ...
# 9370  ff812cf5.wav             Bass_drum                  Knock
# 9371  ff81cc5d.wav             Saxophone                  Flute
# 9372  ff85f513.wav             Bass_drum        Finger_snapping
# 9373  ff8c555d.wav    Gunshot_or_gunfire              Fireworks
# 9374  ff8cfb2d.wav           Double_bass                  Knock
# 9375  ff927bb1.wav              Clarinet              Saxophone
# 9376  ff96680f.wav                  Meow                 Squeak
# 9377  ff97972c.wav              Clarinet                Trumpet
# 9378  ffa502ed.wav              Clarinet              Saxophone
# 9379  ffa69cfc.wav             Telephone         Electric_piano
# 9380  ffaca82d.wav              Scissors          Keys_jangling
# 9381  ffae796c.wav               Trumpet              Saxophone
# 9382  ffb6eb52.wav               Cowbell  Burping_or_eructation
# 9383  ffb6f4da.wav             Bass_drum     Gunshot_or_gunfire
# 9384  ffb75ce0.wav       Acoustic_guitar           Glockenspiel
# 9385  ffba7963.wav              Clarinet                  Flute
# 9386  ffbc5fb8.wav                 Cello              Saxophone
# 9387  ffbe4fbf.wav               Trumpet                  Flute
# 9388  ffc9555f.wav          Glockenspiel        Finger_snapping
# 9389  ffd137a4.wav       Acoustic_guitar         Electric_piano
# 9390  ffd48624.wav               Trumpet                  Cello
# 9391  ffd5e900.wav               Trumpet                  Cello
# 9392  ffd64be4.wav  Drawer_open_or_close             Snare_drum
# 9393  ffd6e84f.wav             Bass_drum            Double_bass
# 9394  ffd9d282.wav              Clarinet                   Oboe
# 9395  ffe76321.wav    Gunshot_or_gunfire              Bass_drum
# 9396  ffe8d42d.wav       Acoustic_guitar      Computer_keyboard
# 9397  ffeba2cd.wav                 Cello              Harmonica
# 9398  fff6d073.wav             Bass_drum            Double_bass
# 9399  fff8d22d.wav                Squeak                   Meow
#
#                           3    lp
# 0                Tambourine  none
# 1          Violin_or_fiddle  none
# 2        Gunshot_or_gunfire  none
# 3               Double_bass  none
# 4                 Bass_drum  none
# 5                     Knock  none
# 6                 Telephone  none
# 7                  Clarinet  none
# 8                 Telephone  none
# 9                     Cello  none
# 10                    Flute  none
# 11                    Cello  none
# 12                      Bus  none
# 13                Bass_drum  none
# 14                  Trumpet  none
# 15              Double_bass  none
# 16             Glockenspiel  none
# 17          Finger_snapping  none
# 18                    Cello  none
# 19                   Hi-hat  none
# 20                     Oboe  none
# 21                  Trumpet  none
# 22                 Clarinet  none
# 23             Glockenspiel  none
# 24          Acoustic_guitar  none
# 25            Keys_jangling  none
# 26       Gunshot_or_gunfire  none
# 27            Keys_jangling  none
# 28                Saxophone  none
# 29       Gunshot_or_gunfire  none
# ...                     ...   ...
# 9370     Gunshot_or_gunfire  none
# 9371               Applause  none
# 9372                  Knock  none
# 9373              Bass_drum  none
# 9374         Electric_piano  none
# 9375                   Oboe  none
# 9376               Laughter  none
# 9377                  Flute  none
# 9378                  Flute  none
# 9379        Acoustic_guitar  none
# 9380        Finger_snapping  none
# 9381               Applause  none
# 9382       Violin_or_fiddle  none
# 9383  Burping_or_eructation  none
# 9384         Electric_piano  none
# 9385              Saxophone  none
# 9386                Trumpet  none
# 9387              Saxophone  none
# 9388         Microwave_oven  none
# 9389           Glockenspiel  none
# 9390               Clarinet  none
# 9391               Clarinet  none
# 9392                 Squeak  none
# 9393   Drawer_open_or_close  none
# 9394                   Gong  none
# 9395                   Fart  none
# 9396                  Knock  none
# 9397       Violin_or_fiddle  none
# 9398                  Knock  none
# 9399                   Fart  none
#
# [9400 rows x 5 columns]

# %% [markdown]
# ## stacking stage2 prediction

# %%
folder = 'data/stacking/lp_model_res/' 
files = os.listdir(folder)
# print(files)

# %%
df_un_ans = pd.DataFrame()
for fold in files:
    un_ans = np.load(folder+fold)
    df = pd.DataFrame(un_ans).T
    df_un_ans = df_un_ans.append(df)
col_list = []
for col_num in range(len(df_un_ans.columns)):

    counter = df_un_ans[col_num].value_counts()

    col_list.append(dict(counter))

print(len(col_list) )
# Out:
# 9400

# %%
take_list=[]
take_label=[]
for i,stats in enumerate(col_list):
    if max(stats.values()) >=len(files):
        take_list.append(i)
        ens_label = max(stats.keys(), key=(lambda k: stats[k]))
        take_label.append(ens_label)
print(len(take_list))
# Out:
# 4523

# %%
for i,row in enumerate(take_list):
    df_ens.iloc[row,4]=take_label[i]
df_ens['lp']=df_ens.lp.map(reverse_dict)
# df_ens
# Out:
#              fname                     1                      2  \
# 0     00063640.wav               Shatter          Keys_jangling
# 1     0013a1db.wav                 Flute                Trumpet
# 2     002bb878.wav             Bass_drum                  Knock
# 3     002d392d.wav             Bass_drum                  Knock
# 4     00326aa9.wav                  Oboe               Clarinet
# 5     0038a046.wav             Bass_drum         Electric_piano
# 6     003995fa.wav                Squeak               Clarinet
# 7     005ae625.wav       Acoustic_guitar                  Cello
# 8     007759c4.wav              Clarinet                  Flute
# 9     008afd93.wav             Saxophone                  Flute
# 10    00a161c0.wav                 Cello               Clarinet
# 11    00a7a2f6.wav              Clarinet                Trumpet
# 12    00ae03f6.wav                 Chime              Telephone
# 13    00b2404e.wav                 Cello            Double_bass
# 14    00beb030.wav              Clarinet                   Oboe
# 15    00c4d5b8.wav       Acoustic_guitar                   Gong
# 16    00c92c05.wav       Acoustic_guitar               Clarinet
# 17    00ccf065.wav             Bass_drum                  Flute
# 18    00d0ab77.wav              Clarinet                Trumpet
# 19    00dffe3a.wav             Bass_drum                  Knock
# 20    00e33205.wav              Clarinet                Trumpet
# 21    00e7ed07.wav                 Flute              Saxophone
# 22    00eac343.wav        Electric_piano              Telephone
# 23    00f2f692.wav                Hi-hat       Violin_or_fiddle
# 24    0102a895.wav                 Cello            Double_bass
# 25    010a0b3a.wav               Shatter             Tambourine
# 26    010eed01.wav               Trumpet                  Knock
# 27    01115622.wav               Shatter                 Hi-hat
# 28    01198b7e.wav              Clarinet                   Oboe
# 29    01207ce5.wav               Tearing          Keys_jangling
# ...            ...                   ...                    ...
# 9370  ff812cf5.wav             Bass_drum                  Knock
# 9371  ff81cc5d.wav             Saxophone                  Flute
# 9372  ff85f513.wav             Bass_drum        Finger_snapping
# 9373  ff8c555d.wav    Gunshot_or_gunfire              Fireworks
# 9374  ff8cfb2d.wav           Double_bass                  Knock
# 9375  ff927bb1.wav              Clarinet              Saxophone
# 9376  ff96680f.wav                  Meow                 Squeak
# 9377  ff97972c.wav              Clarinet                Trumpet
# 9378  ffa502ed.wav              Clarinet              Saxophone
# 9379  ffa69cfc.wav             Telephone         Electric_piano
# 9380  ffaca82d.wav              Scissors          Keys_jangling
# 9381  ffae796c.wav               Trumpet              Saxophone
# 9382  ffb6eb52.wav               Cowbell  Burping_or_eructation
# 9383  ffb6f4da.wav             Bass_drum     Gunshot_or_gunfire
# 9384  ffb75ce0.wav       Acoustic_guitar           Glockenspiel
# 9385  ffba7963.wav              Clarinet                  Flute
# 9386  ffbc5fb8.wav                 Cello              Saxophone
# 9387  ffbe4fbf.wav               Trumpet                  Flute
# 9388  ffc9555f.wav          Glockenspiel        Finger_snapping
# 9389  ffd137a4.wav       Acoustic_guitar         Electric_piano
# 9390  ffd48624.wav               Trumpet                  Cello
# 9391  ffd5e900.wav               Trumpet                  Cello
# 9392  ffd64be4.wav  Drawer_open_or_close             Snare_drum
# 9393  ffd6e84f.wav             Bass_drum            Double_bass
# 9394  ffd9d282.wav              Clarinet                   Oboe
# 9395  ffe76321.wav    Gunshot_or_gunfire              Bass_drum
# 9396  ffe8d42d.wav       Acoustic_guitar      Computer_keyboard
# 9397  ffeba2cd.wav                 Cello              Harmonica
# 9398  fff6d073.wav             Bass_drum            Double_bass
# 9399  fff8d22d.wav                Squeak                   Meow
#
#                           3               lp
# 0                Tambourine              NaN
# 1          Violin_or_fiddle            Flute
# 2        Gunshot_or_gunfire              NaN
# 3               Double_bass        Bass_drum
# 4                 Bass_drum              NaN
# 5                     Knock              NaN
# 6                 Telephone              NaN
# 7                  Clarinet              NaN
# 8                 Telephone              NaN
# 9                     Cello        Saxophone
# 10                    Flute              NaN
# 11                    Cello         Clarinet
# 12                      Bus            Chime
# 13                Bass_drum              NaN
# 14                  Trumpet         Clarinet
# 15              Double_bass  Acoustic_guitar
# 16             Glockenspiel  Acoustic_guitar
# 17          Finger_snapping        Bass_drum
# 18                    Cello         Clarinet
# 19                   Hi-hat        Bass_drum
# 20                     Oboe         Clarinet
# 21                  Trumpet            Flute
# 22                 Clarinet              NaN
# 23             Glockenspiel              NaN
# 24          Acoustic_guitar              NaN
# 25            Keys_jangling              NaN
# 26       Gunshot_or_gunfire              NaN
# 27            Keys_jangling          Shatter
# 28                Saxophone         Clarinet
# 29       Gunshot_or_gunfire              NaN
# ...                     ...              ...
# 9370     Gunshot_or_gunfire        Bass_drum
# 9371               Applause        Saxophone
# 9372                  Knock        Bass_drum
# 9373              Bass_drum              NaN
# 9374         Electric_piano              NaN
# 9375                   Oboe         Clarinet
# 9376               Laughter             Meow
# 9377                  Flute         Clarinet
# 9378                  Flute         Clarinet
# 9379        Acoustic_guitar        Telephone
# 9380        Finger_snapping         Scissors
# 9381               Applause          Trumpet
# 9382       Violin_or_fiddle              NaN
# 9383  Burping_or_eructation              NaN
# 9384         Electric_piano  Acoustic_guitar
# 9385              Saxophone         Clarinet
# 9386                Trumpet              NaN
# 9387              Saxophone          Trumpet
# 9388         Microwave_oven              NaN
# 9389           Glockenspiel  Acoustic_guitar
# 9390               Clarinet              NaN
# 9391               Clarinet          Trumpet
# 9392                 Squeak              NaN
# 9393   Drawer_open_or_close              NaN
# 9394                   Gong         Clarinet
# 9395                   Fart              NaN
# 9396                  Knock              NaN
# 9397       Violin_or_fiddle              NaN
# 9398                  Knock        Bass_drum
# 9399                   Fart              NaN
#
# [9400 rows x 5 columns]

# %% [markdown]
# ## stacking stage2 model prediction

# %%
folder = 'data/stacking/nn/' 
files = os.listdir(folder)
# print(files)

# %%
un_or_test = 'stack'
acc_df = pd.read_csv('data/stacking/stack_accF.csv') # acc csv檔名格式: (csv,acc)
# acc_df.columns = ['unverified','test','acc']
acc_df.columns = [un_or_test,'acc']
# acc_df = acc_df.filter([un_or_test,'acc'])

ratio_all=0
for i,csv in enumerate(files):
    if csv.startswith('valid_acc'):
        continue
    else:
        ratio = acc_df[acc_df[un_or_test] == csv]['acc'].values[0]
#         print(ratio)
        ratio_all += ratio
    df = np.load(folder+csv)#pd.read_csv(os.path.join(folder,csv)) #ori method
#     df = pd.read_csv(os.path.join(folder,csv),header=0,index_col=0) # new method
#     df.sort_values("fname", inplace=True)
#     if df.iloc[0,0] == 'fname':
#         df = df.drop(0,axis=0)
#     df = df.drop(0,axis=1) #ori method
#     df = df.drop(['fname'],axis=1) #mew mthod

    if i==0:
        train_X = df*ratio #+ 8e-3
    else:
        train_X += df*ratio #+ 1e-2
#         train_X *= df**ratio + 8e-3
#         except:
#             train_X += df.values[5763:]*ratio
print(train_X.shape)
# train_X = train_X ** (1/ratio_all)
train_X = train_X /ratio_all
print(sum(train_X[0]),sum(train_X[500]),sum(train_X[2500]))
print(sum(sum(train_X))/9400)
reverse_dict = pickle.load(open('data/map_reverse.pkl' , 'rb'))
# Out:
# (9400, 41)
# 3.3805928602814674 2.692014591768384 2.6880198027938604
# 3.735109649008893

# %%
fname_test = pd.read_csv('data/sample_submission.csv')
fname_test['label'] = 'none'
for i,r in fname_test.iterrows():
    top3 = train_X[i].argsort()[-1:][::-1]
    result = [reverse_dict[x] for x in top3]
    s = ' '.join(result)
    fname_test.iloc[i,1] = s#np.argmax(train_X[i])
#     fname.iloc[i,3] = max(train_X[i])
fname_test.columns = ['fname','stack']
# fname_test
# Out:
#              fname                 stack
# 0     00063640.wav               Shatter
# 1     0013a1db.wav                 Flute
# 2     002bb878.wav             Bass_drum
# 3     002d392d.wav             Bass_drum
# 4     00326aa9.wav                  Oboe
# 5     0038a046.wav             Bass_drum
# 6     003995fa.wav                Squeak
# 7     005ae625.wav       Acoustic_guitar
# 8     007759c4.wav                 Flute
# 9     008afd93.wav             Saxophone
# 10    00a161c0.wav                 Cello
# 11    00a7a2f6.wav              Clarinet
# 12    00ae03f6.wav                 Chime
# 13    00b2404e.wav                 Cello
# 14    00beb030.wav              Clarinet
# 15    00c4d5b8.wav       Acoustic_guitar
# 16    00c92c05.wav       Acoustic_guitar
# 17    00ccf065.wav             Bass_drum
# 18    00d0ab77.wav              Clarinet
# 19    00dffe3a.wav             Bass_drum
# 20    00e33205.wav              Clarinet
# 21    00e7ed07.wav                 Flute
# 22    00eac343.wav        Electric_piano
# 23    00f2f692.wav                Hi-hat
# 24    0102a895.wav                 Cello
# 25    010a0b3a.wav               Shatter
# 26    010eed01.wav               Trumpet
# 27    01115622.wav               Shatter
# 28    01198b7e.wav              Clarinet
# 29    01207ce5.wav               Tearing
# ...            ...                   ...
# 9370  ff812cf5.wav             Bass_drum
# 9371  ff81cc5d.wav             Saxophone
# 9372  ff85f513.wav             Bass_drum
# 9373  ff8c555d.wav    Gunshot_or_gunfire
# 9374  ff8cfb2d.wav           Double_bass
# 9375  ff927bb1.wav              Clarinet
# 9376  ff96680f.wav                  Meow
# 9377  ff97972c.wav              Clarinet
# 9378  ffa502ed.wav              Clarinet
# 9379  ffa69cfc.wav             Telephone
# 9380  ffaca82d.wav              Scissors
# 9381  ffae796c.wav               Trumpet
# 9382  ffb6eb52.wav               Cowbell
# 9383  ffb6f4da.wav             Bass_drum
# 9384  ffb75ce0.wav       Acoustic_guitar
# 9385  ffba7963.wav              Clarinet
# 9386  ffbc5fb8.wav                 Cello
# 9387  ffbe4fbf.wav               Trumpet
# 9388  ffc9555f.wav        Microwave_oven
# 9389  ffd137a4.wav       Acoustic_guitar
# 9390  ffd48624.wav               Trumpet
# 9391  ffd5e900.wav               Trumpet
# 9392  ffd64be4.wav  Drawer_open_or_close
# 9393  ffd6e84f.wav             Bass_drum
# 9394  ffd9d282.wav              Clarinet
# 9395  ffe76321.wav    Gunshot_or_gunfire
# 9396  ffe8d42d.wav       Acoustic_guitar
# 9397  ffeba2cd.wav                 Cello
# 9398  fff6d073.wav             Bass_drum
# 9399  fff8d22d.wav                Squeak
#
# [9400 rows x 2 columns]

# %%
df_all = pd.merge(df_ens,fname_test,how='inner',on='fname')
# df_all = pd.read_csv('result/df_all.csv')
df_all.fillna('none',inplace=True)
print(df_all)
# Out:
#              fname                     1                      2  \
# 0     00063640.wav               Shatter          Keys_jangling
# 1     0013a1db.wav                 Flute                Trumpet
# 2     002bb878.wav             Bass_drum                  Knock
# 3     002d392d.wav             Bass_drum                  Knock
# 4     00326aa9.wav                  Oboe               Clarinet
# 5     0038a046.wav             Bass_drum         Electric_piano
# 6     003995fa.wav                Squeak               Clarinet
# 7     005ae625.wav       Acoustic_guitar                  Cello
# 8     007759c4.wav              Clarinet                  Flute
# 9     008afd93.wav             Saxophone                  Flute
# 10    00a161c0.wav                 Cello               Clarinet
# 11    00a7a2f6.wav              Clarinet                Trumpet
# 12    00ae03f6.wav                 Chime              Telephone
# 13    00b2404e.wav                 Cello            Double_bass
# 14    00beb030.wav              Clarinet                   Oboe
# 15    00c4d5b8.wav       Acoustic_guitar                   Gong
# 16    00c92c05.wav       Acoustic_guitar               Clarinet
# 17    00ccf065.wav             Bass_drum                  Flute
# 18    00d0ab77.wav              Clarinet                Trumpet
# 19    00dffe3a.wav             Bass_drum                  Knock
# 20    00e33205.wav              Clarinet                Trumpet
# 21    00e7ed07.wav                 Flute              Saxophone
# 22    00eac343.wav        Electric_piano              Telephone
# 23    00f2f692.wav                Hi-hat       Violin_or_fiddle
# 24    0102a895.wav                 Cello            Double_bass
# 25    010a0b3a.wav               Shatter             Tambourine
# 26    010eed01.wav               Trumpet                  Knock
# 27    01115622.wav               Shatter                 Hi-hat
# 28    01198b7e.wav              Clarinet                   Oboe
# 29    01207ce5.wav               Tearing          Keys_jangling
# ...            ...                   ...                    ...
# 9370  ff812cf5.wav             Bass_drum                  Knock
# 9371  ff81cc5d.wav             Saxophone                  Flute
# 9372  ff85f513.wav             Bass_drum        Finger_snapping
# 9373  ff8c555d.wav    Gunshot_or_gunfire              Fireworks
# 9374  ff8cfb2d.wav           Double_bass                  Knock
# 9375  ff927bb1.wav              Clarinet              Saxophone
# 9376  ff96680f.wav                  Meow                 Squeak
# 9377  ff97972c.wav              Clarinet                Trumpet
# 9378  ffa502ed.wav              Clarinet              Saxophone
# 9379  ffa69cfc.wav             Telephone         Electric_piano
# 9380  ffaca82d.wav              Scissors          Keys_jangling
# 9381  ffae796c.wav               Trumpet              Saxophone
# 9382  ffb6eb52.wav               Cowbell  Burping_or_eructation
# 9383  ffb6f4da.wav             Bass_drum     Gunshot_or_gunfire
# 9384  ffb75ce0.wav       Acoustic_guitar           Glockenspiel
# 9385  ffba7963.wav              Clarinet                  Flute
# 9386  ffbc5fb8.wav                 Cello              Saxophone
# 9387  ffbe4fbf.wav               Trumpet                  Flute
# 9388  ffc9555f.wav          Glockenspiel        Finger_snapping
# 9389  ffd137a4.wav       Acoustic_guitar         Electric_piano
# 9390  ffd48624.wav               Trumpet                  Cello
# 9391  ffd5e900.wav               Trumpet                  Cello
# 9392  ffd64be4.wav  Drawer_open_or_close             Snare_drum
# 9393  ffd6e84f.wav             Bass_drum            Double_bass
# 9394  ffd9d282.wav              Clarinet                   Oboe
# 9395  ffe76321.wav    Gunshot_or_gunfire              Bass_drum
# 9396  ffe8d42d.wav       Acoustic_guitar      Computer_keyboard
# 9397  ffeba2cd.wav                 Cello              Harmonica
# 9398  fff6d073.wav             Bass_drum            Double_bass
# 9399  fff8d22d.wav                Squeak                   Meow
#
#                           3               lp                 stack
# 0                Tambourine             none               Shatter
# 1          Violin_or_fiddle            Flute                 Flute
# 2        Gunshot_or_gunfire             none             Bass_drum
# 3               Double_bass        Bass_drum             Bass_drum
# 4                 Bass_drum             none                  Oboe
# 5                     Knock             none             Bass_drum
# 6                 Telephone             none                Squeak
# 7                  Clarinet             none       Acoustic_guitar
# 8                 Telephone             none                 Flute
# 9                     Cello        Saxophone             Saxophone
# 10                    Flute             none                 Cello
# 11                    Cello         Clarinet              Clarinet
# 12                      Bus            Chime                 Chime
# 13                Bass_drum             none                 Cello
# 14                  Trumpet         Clarinet              Clarinet
# 15              Double_bass  Acoustic_guitar       Acoustic_guitar
# 16             Glockenspiel  Acoustic_guitar       Acoustic_guitar
# 17          Finger_snapping        Bass_drum             Bass_drum
# 18                    Cello         Clarinet              Clarinet
# 19                   Hi-hat        Bass_drum             Bass_drum
# 20                     Oboe         Clarinet              Clarinet
# 21                  Trumpet            Flute                 Flute
# 22                 Clarinet             none        Electric_piano
# 23             Glockenspiel             none                Hi-hat
# 24          Acoustic_guitar             none                 Cello
# 25            Keys_jangling             none               Shatter
# 26       Gunshot_or_gunfire             none               Trumpet
# 27            Keys_jangling          Shatter               Shatter
# 28                Saxophone         Clarinet              Clarinet
# 29       Gunshot_or_gunfire             none               Tearing
# ...                     ...              ...                   ...
# 9370     Gunshot_or_gunfire        Bass_drum             Bass_drum
# 9371               Applause        Saxophone             Saxophone
# 9372                  Knock        Bass_drum             Bass_drum
# 9373              Bass_drum             none    Gunshot_or_gunfire
# 9374         Electric_piano             none           Double_bass
# 9375                   Oboe         Clarinet              Clarinet
# 9376               Laughter             Meow                  Meow
# 9377                  Flute         Clarinet              Clarinet
# 9378                  Flute         Clarinet              Clarinet
# 9379        Acoustic_guitar        Telephone             Telephone
# 9380        Finger_snapping         Scissors              Scissors
# 9381               Applause          Trumpet               Trumpet
# 9382       Violin_or_fiddle             none               Cowbell
# 9383  Burping_or_eructation             none             Bass_drum
# 9384         Electric_piano  Acoustic_guitar       Acoustic_guitar
# 9385              Saxophone         Clarinet              Clarinet
# 9386                Trumpet             none                 Cello
# 9387              Saxophone          Trumpet               Trumpet
# 9388         Microwave_oven             none        Microwave_oven
# 9389           Glockenspiel  Acoustic_guitar       Acoustic_guitar
# 9390               Clarinet             none               Trumpet
# 9391               Clarinet          Trumpet               Trumpet
# 9392                 Squeak             none  Drawer_open_or_close
# 9393   Drawer_open_or_close             none             Bass_drum
# 9394                   Gong         Clarinet              Clarinet
# 9395                   Fart             none    Gunshot_or_gunfire
# 9396                  Knock             none       Acoustic_guitar
# 9397       Violin_or_fiddle             none                 Cello
# 9398                  Knock        Bass_drum             Bass_drum
# 9399                   Fart             none                Squeak
#
# [9400 rows x 6 columns]

# %%
def one(x):
    if x['lp'] != 'none':
        return x['lp']
    else:
        return x['stack']
def two(x):
    if x['fin1'] == x['stack'] == x['1']:
        return x['2']
    elif x['fin1'] == x['stack']:
        return x['1']
    else:
        return x['stack']
def three(x):
    if x['fin2'] == x['1']:
        return x['2']
    elif x['fin2'] == x['2']:
        return x['3']
    else:
        return x['1']

# %%
df_all['fin1'] = df_all.apply(one,axis=1)
df_all['fin2'] = df_all.apply(two,axis=1)
df_all['fin3'] = df_all.apply(three,axis=1)
df_all['final'] = df_all['fin1']+' '+df_all['fin2']+' '+df_all['fin3']
# df_all
# Out:
#              fname                     1                      2  \
# 0     00063640.wav               Shatter          Keys_jangling
# 1     0013a1db.wav                 Flute                Trumpet
# 2     002bb878.wav             Bass_drum                  Knock
# 3     002d392d.wav             Bass_drum                  Knock
# 4     00326aa9.wav                  Oboe               Clarinet
# 5     0038a046.wav             Bass_drum         Electric_piano
# 6     003995fa.wav                Squeak               Clarinet
# 7     005ae625.wav       Acoustic_guitar                  Cello
# 8     007759c4.wav              Clarinet                  Flute
# 9     008afd93.wav             Saxophone                  Flute
# 10    00a161c0.wav                 Cello               Clarinet
# 11    00a7a2f6.wav              Clarinet                Trumpet
# 12    00ae03f6.wav                 Chime              Telephone
# 13    00b2404e.wav                 Cello            Double_bass
# 14    00beb030.wav              Clarinet                   Oboe
# 15    00c4d5b8.wav       Acoustic_guitar                   Gong
# 16    00c92c05.wav       Acoustic_guitar               Clarinet
# 17    00ccf065.wav             Bass_drum                  Flute
# 18    00d0ab77.wav              Clarinet                Trumpet
# 19    00dffe3a.wav             Bass_drum                  Knock
# 20    00e33205.wav              Clarinet                Trumpet
# 21    00e7ed07.wav                 Flute              Saxophone
# 22    00eac343.wav        Electric_piano              Telephone
# 23    00f2f692.wav                Hi-hat       Violin_or_fiddle
# 24    0102a895.wav                 Cello            Double_bass
# 25    010a0b3a.wav               Shatter             Tambourine
# 26    010eed01.wav               Trumpet                  Knock
# 27    01115622.wav               Shatter                 Hi-hat
# 28    01198b7e.wav              Clarinet                   Oboe
# 29    01207ce5.wav               Tearing          Keys_jangling
# ...            ...                   ...                    ...
# 9370  ff812cf5.wav             Bass_drum                  Knock
# 9371  ff81cc5d.wav             Saxophone                  Flute
# 9372  ff85f513.wav             Bass_drum        Finger_snapping
# 9373  ff8c555d.wav    Gunshot_or_gunfire              Fireworks
# 9374  ff8cfb2d.wav           Double_bass                  Knock
# 9375  ff927bb1.wav              Clarinet              Saxophone
# 9376  ff96680f.wav                  Meow                 Squeak
# 9377  ff97972c.wav              Clarinet                Trumpet
# 9378  ffa502ed.wav              Clarinet              Saxophone
# 9379  ffa69cfc.wav             Telephone         Electric_piano
# 9380  ffaca82d.wav              Scissors          Keys_jangling
# 9381  ffae796c.wav               Trumpet              Saxophone
# 9382  ffb6eb52.wav               Cowbell  Burping_or_eructation
# 9383  ffb6f4da.wav             Bass_drum     Gunshot_or_gunfire
# 9384  ffb75ce0.wav       Acoustic_guitar           Glockenspiel
# 9385  ffba7963.wav              Clarinet                  Flute
# 9386  ffbc5fb8.wav                 Cello              Saxophone
# 9387  ffbe4fbf.wav               Trumpet                  Flute
# 9388  ffc9555f.wav          Glockenspiel        Finger_snapping
# 9389  ffd137a4.wav       Acoustic_guitar         Electric_piano
# 9390  ffd48624.wav               Trumpet                  Cello
# 9391  ffd5e900.wav               Trumpet                  Cello
# 9392  ffd64be4.wav  Drawer_open_or_close             Snare_drum
# 9393  ffd6e84f.wav             Bass_drum            Double_bass
# 9394  ffd9d282.wav              Clarinet                   Oboe
# 9395  ffe76321.wav    Gunshot_or_gunfire              Bass_drum
# 9396  ffe8d42d.wav       Acoustic_guitar      Computer_keyboard
# 9397  ffeba2cd.wav                 Cello              Harmonica
# 9398  fff6d073.wav             Bass_drum            Double_bass
# 9399  fff8d22d.wav                Squeak                   Meow
#
#                           3               lp                 stack  \
# 0                Tambourine             none               Shatter
# 1          Violin_or_fiddle            Flute                 Flute
# 2        Gunshot_or_gunfire             none             Bass_drum
# 3               Double_bass        Bass_drum             Bass_drum
# 4                 Bass_drum             none                  Oboe
# 5                     Knock             none             Bass_drum
# 6                 Telephone             none                Squeak
# 7                  Clarinet             none       Acoustic_guitar
# 8                 Telephone             none                 Flute
# 9                     Cello        Saxophone             Saxophone
# 10                    Flute             none                 Cello
# 11                    Cello         Clarinet              Clarinet
# 12                      Bus            Chime                 Chime
# 13                Bass_drum             none                 Cello
# 14                  Trumpet         Clarinet              Clarinet
# 15              Double_bass  Acoustic_guitar       Acoustic_guitar
# 16             Glockenspiel  Acoustic_guitar       Acoustic_guitar
# 17          Finger_snapping        Bass_drum             Bass_drum
# 18                    Cello         Clarinet              Clarinet
# 19                   Hi-hat        Bass_drum             Bass_drum
# 20                     Oboe         Clarinet              Clarinet
# 21                  Trumpet            Flute                 Flute
# 22                 Clarinet             none        Electric_piano
# 23             Glockenspiel             none                Hi-hat
# 24          Acoustic_guitar             none                 Cello
# 25            Keys_jangling             none               Shatter
# 26       Gunshot_or_gunfire             none               Trumpet
# 27            Keys_jangling          Shatter               Shatter
# 28                Saxophone         Clarinet              Clarinet
# 29       Gunshot_or_gunfire             none               Tearing
# ...                     ...              ...                   ...
# 9370     Gunshot_or_gunfire        Bass_drum             Bass_drum
# 9371               Applause        Saxophone             Saxophone
# 9372                  Knock        Bass_drum             Bass_drum
# 9373              Bass_drum             none    Gunshot_or_gunfire
# 9374         Electric_piano             none           Double_bass
# 9375                   Oboe         Clarinet              Clarinet
# 9376               Laughter             Meow                  Meow
# 9377                  Flute         Clarinet              Clarinet
# 9378                  Flute         Clarinet              Clarinet
# 9379        Acoustic_guitar        Telephone             Telephone
# 9380        Finger_snapping         Scissors              Scissors
# 9381               Applause          Trumpet               Trumpet
# 9382       Violin_or_fiddle             none               Cowbell
# 9383  Burping_or_eructation             none             Bass_drum
# 9384         Electric_piano  Acoustic_guitar       Acoustic_guitar
# 9385              Saxophone         Clarinet              Clarinet
# 9386                Trumpet             none                 Cello
# 9387              Saxophone          Trumpet               Trumpet
# 9388         Microwave_oven             none        Microwave_oven
# 9389           Glockenspiel  Acoustic_guitar       Acoustic_guitar
# 9390               Clarinet             none               Trumpet
# 9391               Clarinet          Trumpet               Trumpet
# 9392                 Squeak             none  Drawer_open_or_close
# 9393   Drawer_open_or_close             none             Bass_drum
# 9394                   Gong         Clarinet              Clarinet
# 9395                   Fart             none    Gunshot_or_gunfire
# 9396                  Knock             none       Acoustic_guitar
# 9397       Violin_or_fiddle             none                 Cello
# 9398                  Knock        Bass_drum             Bass_drum
# 9399                   Fart             none                Squeak
#
#                       fin1                   fin2                   fin3  \
# 0                  Shatter          Keys_jangling             Tambourine
# 1                    Flute                Trumpet       Violin_or_fiddle
# 2                Bass_drum                  Knock     Gunshot_or_gunfire
# 3                Bass_drum                  Knock            Double_bass
# 4                     Oboe               Clarinet              Bass_drum
# 5                Bass_drum         Electric_piano                  Knock
# 6                   Squeak               Clarinet              Telephone
# 7          Acoustic_guitar                  Cello               Clarinet
# 8                    Flute               Clarinet                  Flute
# 9                Saxophone                  Flute                  Cello
# 10                   Cello               Clarinet                  Flute
# 11                Clarinet                Trumpet                  Cello
# 12                   Chime              Telephone                    Bus
# 13                   Cello            Double_bass              Bass_drum
# 14                Clarinet                   Oboe                Trumpet
# 15         Acoustic_guitar                   Gong            Double_bass
# 16         Acoustic_guitar               Clarinet           Glockenspiel
# 17               Bass_drum                  Flute        Finger_snapping
# 18                Clarinet                Trumpet                  Cello
# 19               Bass_drum                  Knock                 Hi-hat
# 20                Clarinet                Trumpet                   Oboe
# 21                   Flute              Saxophone                Trumpet
# 22          Electric_piano              Telephone               Clarinet
# 23                  Hi-hat       Violin_or_fiddle           Glockenspiel
# 24                   Cello            Double_bass        Acoustic_guitar
# 25                 Shatter             Tambourine          Keys_jangling
# 26                 Trumpet                  Knock     Gunshot_or_gunfire
# 27                 Shatter                 Hi-hat          Keys_jangling
# 28                Clarinet                   Oboe              Saxophone
# 29                 Tearing          Keys_jangling     Gunshot_or_gunfire
# ...                    ...                    ...                    ...
# 9370             Bass_drum                  Knock     Gunshot_or_gunfire
# 9371             Saxophone                  Flute               Applause
# 9372             Bass_drum        Finger_snapping                  Knock
# 9373    Gunshot_or_gunfire              Fireworks              Bass_drum
# 9374           Double_bass                  Knock         Electric_piano
# 9375              Clarinet              Saxophone                   Oboe
# 9376                  Meow                 Squeak               Laughter
# 9377              Clarinet                Trumpet                  Flute
# 9378              Clarinet              Saxophone                  Flute
# 9379             Telephone         Electric_piano        Acoustic_guitar
# 9380              Scissors          Keys_jangling        Finger_snapping
# 9381               Trumpet              Saxophone               Applause
# 9382               Cowbell  Burping_or_eructation       Violin_or_fiddle
# 9383             Bass_drum     Gunshot_or_gunfire  Burping_or_eructation
# 9384       Acoustic_guitar           Glockenspiel         Electric_piano
# 9385              Clarinet                  Flute              Saxophone
# 9386                 Cello              Saxophone                Trumpet
# 9387               Trumpet                  Flute              Saxophone
# 9388        Microwave_oven           Glockenspiel        Finger_snapping
# 9389       Acoustic_guitar         Electric_piano           Glockenspiel
# 9390               Trumpet                  Cello               Clarinet
# 9391               Trumpet                  Cello               Clarinet
# 9392  Drawer_open_or_close             Snare_drum                 Squeak
# 9393             Bass_drum            Double_bass   Drawer_open_or_close
# 9394              Clarinet                   Oboe                   Gong
# 9395    Gunshot_or_gunfire              Bass_drum                   Fart
# 9396       Acoustic_guitar      Computer_keyboard                  Knock
# 9397                 Cello              Harmonica       Violin_or_fiddle
# 9398             Bass_drum            Double_bass                  Knock
# 9399                Squeak                   Meow                   Fart
#
#                                                   final
# 0                      Shatter Keys_jangling Tambourine
# 1                        Flute Trumpet Violin_or_fiddle
# 2                    Bass_drum Knock Gunshot_or_gunfire
# 3                           Bass_drum Knock Double_bass
# 4                               Oboe Clarinet Bass_drum
# 5                        Bass_drum Electric_piano Knock
# 6                             Squeak Clarinet Telephone
# 7                        Acoustic_guitar Cello Clarinet
# 8                                  Flute Clarinet Flute
# 9                                 Saxophone Flute Cello
# 10                                 Cello Clarinet Flute
# 11                               Clarinet Trumpet Cello
# 12                                  Chime Telephone Bus
# 13                          Cello Double_bass Bass_drum
# 14                                Clarinet Oboe Trumpet
# 15                     Acoustic_guitar Gong Double_bass
# 16                Acoustic_guitar Clarinet Glockenspiel
# 17                      Bass_drum Flute Finger_snapping
# 18                               Clarinet Trumpet Cello
# 19                               Bass_drum Knock Hi-hat
# 20                                Clarinet Trumpet Oboe
# 21                              Flute Saxophone Trumpet
# 22                    Electric_piano Telephone Clarinet
# 23                 Hi-hat Violin_or_fiddle Glockenspiel
# 24                    Cello Double_bass Acoustic_guitar
# 25                     Shatter Tambourine Keys_jangling
# 26                     Trumpet Knock Gunshot_or_gunfire
# 27                         Shatter Hi-hat Keys_jangling
# 28                              Clarinet Oboe Saxophone
# 29             Tearing Keys_jangling Gunshot_or_gunfire
# ...                                                 ...
# 9370                 Bass_drum Knock Gunshot_or_gunfire
# 9371                           Saxophone Flute Applause
# 9372                    Bass_drum Finger_snapping Knock
# 9373             Gunshot_or_gunfire Fireworks Bass_drum
# 9374                   Double_bass Knock Electric_piano
# 9375                            Clarinet Saxophone Oboe
# 9376                               Meow Squeak Laughter
# 9377                             Clarinet Trumpet Flute
# 9378                           Clarinet Saxophone Flute
# 9379           Telephone Electric_piano Acoustic_guitar
# 9380             Scissors Keys_jangling Finger_snapping
# 9381                         Trumpet Saxophone Applause
# 9382     Cowbell Burping_or_eructation Violin_or_fiddle
# 9383  Bass_drum Gunshot_or_gunfire Burping_or_eructa...
# 9384        Acoustic_guitar Glockenspiel Electric_piano
# 9385                           Clarinet Flute Saxophone
# 9386                            Cello Saxophone Trumpet
# 9387                            Trumpet Flute Saxophone
# 9388        Microwave_oven Glockenspiel Finger_snapping
# 9389        Acoustic_guitar Electric_piano Glockenspiel
# 9390                             Trumpet Cello Clarinet
# 9391                             Trumpet Cello Clarinet
# 9392             Drawer_open_or_close Snare_drum Squeak
# 9393         Bass_drum Double_bass Drawer_open_or_close
# 9394                                 Clarinet Oboe Gong
# 9395                  Gunshot_or_gunfire Bass_drum Fart
# 9396            Acoustic_guitar Computer_keyboard Knock
# 9397                   Cello Harmonica Violin_or_fiddle
# 9398                        Bass_drum Double_bass Knock
# 9399                                   Squeak Meow Fart
#
# [9400 rows x 10 columns]

# %%
dfF = df_all.filter(['fname','final'])
dfF.columns = ['fname','label']
print(dfF)
# Out:
#              fname                                              label
# 0     00063640.wav                   Shatter Keys_jangling Tambourine
# 1     0013a1db.wav                     Flute Trumpet Violin_or_fiddle
# 2     002bb878.wav                 Bass_drum Knock Gunshot_or_gunfire
# 3     002d392d.wav                        Bass_drum Knock Double_bass
# 4     00326aa9.wav                            Oboe Clarinet Bass_drum
# 5     0038a046.wav                     Bass_drum Electric_piano Knock
# 6     003995fa.wav                          Squeak Clarinet Telephone
# 7     005ae625.wav                     Acoustic_guitar Cello Clarinet
# 8     007759c4.wav                               Flute Clarinet Flute
# 9     008afd93.wav                              Saxophone Flute Cello
# 10    00a161c0.wav                               Cello Clarinet Flute
# 11    00a7a2f6.wav                             Clarinet Trumpet Cello
# 12    00ae03f6.wav                                Chime Telephone Bus
# 13    00b2404e.wav                        Cello Double_bass Bass_drum
# 14    00beb030.wav                              Clarinet Oboe Trumpet
# 15    00c4d5b8.wav                   Acoustic_guitar Gong Double_bass
# 16    00c92c05.wav              Acoustic_guitar Clarinet Glockenspiel
# 17    00ccf065.wav                    Bass_drum Flute Finger_snapping
# 18    00d0ab77.wav                             Clarinet Trumpet Cello
# 19    00dffe3a.wav                             Bass_drum Knock Hi-hat
# 20    00e33205.wav                              Clarinet Trumpet Oboe
# 21    00e7ed07.wav                            Flute Saxophone Trumpet
# 22    00eac343.wav                  Electric_piano Telephone Clarinet
# 23    00f2f692.wav               Hi-hat Violin_or_fiddle Glockenspiel
# 24    0102a895.wav                  Cello Double_bass Acoustic_guitar
# 25    010a0b3a.wav                   Shatter Tambourine Keys_jangling
# 26    010eed01.wav                   Trumpet Knock Gunshot_or_gunfire
# 27    01115622.wav                       Shatter Hi-hat Keys_jangling
# 28    01198b7e.wav                            Clarinet Oboe Saxophone
# 29    01207ce5.wav           Tearing Keys_jangling Gunshot_or_gunfire
# ...            ...                                                ...
# 9370  ff812cf5.wav                 Bass_drum Knock Gunshot_or_gunfire
# 9371  ff81cc5d.wav                           Saxophone Flute Applause
# 9372  ff85f513.wav                    Bass_drum Finger_snapping Knock
# 9373  ff8c555d.wav             Gunshot_or_gunfire Fireworks Bass_drum
# 9374  ff8cfb2d.wav                   Double_bass Knock Electric_piano
# 9375  ff927bb1.wav                            Clarinet Saxophone Oboe
# 9376  ff96680f.wav                               Meow Squeak Laughter
# 9377  ff97972c.wav                             Clarinet Trumpet Flute
# 9378  ffa502ed.wav                           Clarinet Saxophone Flute
# 9379  ffa69cfc.wav           Telephone Electric_piano Acoustic_guitar
# 9380  ffaca82d.wav             Scissors Keys_jangling Finger_snapping
# 9381  ffae796c.wav                         Trumpet Saxophone Applause
# 9382  ffb6eb52.wav     Cowbell Burping_or_eructation Violin_or_fiddle
# 9383  ffb6f4da.wav  Bass_drum Gunshot_or_gunfire Burping_or_eructa...
# 9384  ffb75ce0.wav        Acoustic_guitar Glockenspiel Electric_piano
# 9385  ffba7963.wav                           Clarinet Flute Saxophone
# 9386  ffbc5fb8.wav                            Cello Saxophone Trumpet
# 9387  ffbe4fbf.wav                            Trumpet Flute Saxophone
# 9388  ffc9555f.wav        Microwave_oven Glockenspiel Finger_snapping
# 9389  ffd137a4.wav        Acoustic_guitar Electric_piano Glockenspiel
# 9390  ffd48624.wav                             Trumpet Cello Clarinet
# 9391  ffd5e900.wav                             Trumpet Cello Clarinet
# 9392  ffd64be4.wav             Drawer_open_or_close Snare_drum Squeak
# 9393  ffd6e84f.wav         Bass_drum Double_bass Drawer_open_or_close
# 9394  ffd9d282.wav                                 Clarinet Oboe Gong
# 9395  ffe76321.wav                  Gunshot_or_gunfire Bass_drum Fart
# 9396  ffe8d42d.wav            Acoustic_guitar Computer_keyboard Knock
# 9397  ffeba2cd.wav                   Cello Harmonica Violin_or_fiddle
# 9398  fff6d073.wav                        Bass_drum Double_bass Knock
# 9399  fff8d22d.wav                                   Squeak Meow Fart
#
# [9400 rows x 2 columns]

# %%
dfF.to_csv(predict_path,index=False)
print(predict_path)
# Out:
# result/test_repro3.csv
